# %%
from langchain_deepseek import ChatDeepSeek
from langgraph.checkpoint.memory import InMemorySaver
from langchain.agents import create_agent

model = ChatDeepSeek(
    model="deepseek-chat"
)

agent = create_agent(
    model=model,
    checkpointer=InMemorySaver(),
)

agent.invoke({
    "messages": [{
        "role": "user",
        "content": "你好，我的名字叫陈明。"
    }]}, 
    {
    "configurable": {
        "thread_id": "1"
    }}
)

response = agent.invoke({
    "messages": [{
        "role": "user",
        "content": "请告诉我我的名字。"
    }]},
        {
    "configurable": {
        "thread_id": "1"
    }}
)

for message in response["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 你好，我的名字叫陈明。
# ================================== Ai Message ==================================
#
# 你好，陈明！很高兴认识你！😊
# 我是DeepSeek，一个AI助手，随时准备为你提供帮助。无论是回答问题、协助思考问题，还是日常聊天，我都很乐意陪伴你。
# 有什么我可以为你做的吗？
# ================================ Human Message =================================
#
# 请告诉我我的名字。
# ================================== Ai Message ==================================
#
# 你的名字是**陈明**。 😊
# 如果还有其他问题或需要帮助的地方，随时告诉我哦！
